# %%
# Code for search images in a folder, preprocess, and save
import numpy as np
import os
import re
import imageio as imgio
# %pylab inline
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
#auxiliary functions
def atoi(text):
    return int(text) if text.isdigit() else text
def natural_keys(text):
    '''
    alist.sort(key=natural_keys) sorts in human order
    http://nedbatchelder.com/blog/200712/human_sorting.html
    (See Toothy's implementation in the comments)
    '''
    return [ atoi(c) for c in re.split(r'(\d+)', text) ]

# %%
#function to preprocess an image
def ProcessImage(Img):
    ImgT = np.zeros(Img.shape)
    #preprocessing here!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
    return uint8(ImgT)

# %%
#folder containing original images and folder to save the new images
pathimgs = "D:\\Images"; #path original images
pathsave = "D:\\ImagesPre"; #path to save processed images

#create the list of nii images in the directory
allfiles = os.listdir(os.path.join(pathimgs))
allfiles.sort(key=natural_keys)
newlist = []
for names in allfiles:
    if names.endswith(".png"):
        newlist.append(names)

#process each image
for i in range(len(newlist)):
    img = imread(pathimgs + "\\" + newlist[i])
    imgT = ProcessImage(img)
    imgio.imwrite(pathsave + "\\" + newlist[i],imgT)
